# %% [markdown]
# ## Global Macroeconomic Financial News

# %%
import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime, timedelta

import os
from dotenv import load_dotenv, find_dotenv

# %%
# Use find_dotenv to locate the file
dotenv_path = find_dotenv()

# Load the .env file
load_dotenv(dotenv_path)

# Fetch the specific keys
apikey_openai = os.getenv('apikey_openai')
GOOGLE_CSE_ID = os.getenv('apikey_GOOGLE_CSE_ID')
GOOGLE_API_KEY = os.getenv('apikey_GOOGLE')

# %%
# Get today's date
today = datetime.now()

# Subtract one day
one_day_ago = today - timedelta(days=1)

# Convert it to a string in 'YYYY-MM-DD' format
date_str = one_day_ago.strftime('%Y-%m-%d')
#date_str = today

# %%
# All keywords in a single list
keywords = [
    'finance', 'economy', 'banking', 'inflation', 'GDP', 'Unemployment', 
    'Interest Rate', 'Federal Reserve', 'Fiscal Policy', 'Monetary Policy', 
    'Trade Deficit', 'Balance of Payments', 'Foreign Exchange', 'Derivatives', 
    'Asset Management', 'Hedge Funds', 'Private Equity', 'Venture Capital', 
    'IPO', 'Mergers and Acquisitions', 'Credit Ratings', 'credit swaps','Stock Market', 
    'Recession', 'Economic Growth', 'Inflation Rate', 'Consumer Spending', 
    'Consumer Confidence', 'Retail Sales', 'Industrial Production', 'Consumer Debt',
    'Housing Market', 'Business Cycle', 'Central Bank', 'NFP', 'Unemployment',
    'employment', 'crypto','cryptocurrency', 'Bitcoin', 'BTC','blockchain','ethereum',
    'S&P 500', 'Nasdaq','Dow Jones','crypto exchange'
]

# %%
# Maximum number of keywords per request
max_keywords_per_request = 5  # Adjust this to the maximum allowed by your API

# Number of requests
num_requests = int(np.ceil(len(keywords) / max_keywords_per_request))

# Distribute keywords across requests
requests_keywords = np.array_split(keywords, num_requests)

# Generate URLs
base_url = 'https://newsapi.org/v2/everything?q={}&from={}&sortBy=popularity&apikey={}'
urls = [base_url.format('%20OR%20'.join(kw_list), date_str, apikey_news_source) for kw_list in requests_keywords]

# %%
df = pd.DataFrame()

for url in urls:
    response = requests.get(url).json()
    df_temp = pd.json_normalize(response['articles'])
    df = pd.concat([df, df_temp], ignore_index=True)

df = df.drop_duplicates().reset_index(drop=True)

# %%
df
# Out:
#                                        author  \
# 0            https://www.facebook.com/bbcnews
# 1                                        None
# 2                                        None
# 3                                        None
# 4                              Graeme Wearden
# ..                                        ...
# 743  newsfeedback@fool.com (Selena Maranjian)
# 744    newsfeedback@fool.com (Stefon Walters)
# 745   newsfeedback@fool.com (David Jagielski)
# 746     newsfeedback@fool.com (Keithen Drury)
# 747   newsfeedback@fool.com (Matthew DiLallo)
#
#                                                  title  \
# 0    Hajj: Price rises making pilgrimage increasing...
# 1    Japan finance officials step up warning agains...
# 2    Australia eyes bigger budget surplus but warns...
# 3    Euro zone should tighten fiscal policy in 2024...
# 4    Water bills ‘to surge up to 40%’ to fix sewage...
# ..                                                 ...
# 743  5 Things to Know About Student Loan Interest R...
# 744  Here's One Warren Buffett Investing Strategy t...
# 745  Innovative Industrial Properties Didn't Raise ...
# 746              2 Nasdaq Stocks to Buy Hand Over Fist
# 747  Got $10,000? 4 Dividend Stocks Yielding 4%+ to...
#
#                                            description  \
# 0    The pilgrimage to Mecca is becoming increasing...
# 1    Japan finance officials step up warning agains...
# 2    Australia eyes bigger budget surplus but warns...
# 3    Euro zone should tighten fiscal policy in 2024...
# 4    Rolling coverage of the latest economic and fi...
# ..                                                 ...
# 743  Whether you're already a borrower or plan to b...
# 744  Investors should strive for more diversificati...
# 745   Is the stock's 10% dividend yield due for a cut?
# 746  Alphabet and Autodesk each look fairly priced ...
# 747  These companies supply their investors with re...
#
#                                                    url  \
# 0    https://www.bbc.co.uk/news/world-middle-east-6...
# 1    https://consent.google.com/ml?continue=https:/...
# 2    https://consent.google.com/ml?continue=https:/...
# 3    https://consent.google.com/ml?continue=https:/...
# 4    https://www.theguardian.com/business/live/2023...
# ..                                                 ...
# 743  https://www.fool.com/student-loans/2023/06/28/...
# 744  https://www.fool.com/investing/2023/06/28/here...
# 745  https://www.fool.com/investing/2023/06/28/inno...
# 746  https://www.fool.com/investing/2023/06/28/2-na...
# 747  https://www.fool.com/investing/2023/06/28/got-...
#
#                                             urlToImage           publishedAt  \
# 0    https://ichef.bbci.co.uk/news/1024/branded_new...  2023-06-28T09:32:39Z
# 1                                                 None  2023-06-28T06:56:15Z
# 2                                                 None  2023-06-28T00:00:07Z
# 3                                                 None  2023-06-28T12:22:00Z
# 4    https://i.guim.co.uk/img/media/62a1b9bbbb23318...  2023-06-28T06:06:24Z
# ..                                                 ...                   ...
# 743  https://g.foolcdn.com/editorial/images/737819/...  2023-06-28T12:51:00Z
# 744  https://g.foolcdn.com/editorial/images/737312/...  2023-06-28T12:40:00Z
# 745  https://g.foolcdn.com/editorial/images/737481/...  2023-06-28T11:15:00Z
# 746  https://g.foolcdn.com/editorial/images/737141/...  2023-06-28T10:45:00Z
# 747  https://g.foolcdn.com/editorial/images/737785/...  2023-06-28T11:06:00Z
#
#                                                content    source.id  \
# 0    Some 1.8 million Muslims from across the world...     bbc-news
# 1    We use cookies and data to<ul><li>Deliver and ...  google-news
# 2    We use cookies and data to<ul><li>Deliver and ...  google-news
# 3    We use cookies and data to<ul><li>Deliver and ...  google-news
# 4    Introduction: Water bills "to rise 40% to fix ...         None
# ..                                                 ...          ...
# 743  Interest rates are important. Consider mortgag...         None
# 744  It's no secret that many investors regard Warr...         None
# 745  Innovative Industrial Properties(IIPR 2.05%) o...         None
# 746  Finding companies that can thrive during all m...         None
# 747  Most people are on a monthly income and expens...         None
#
#       source.name
# 0        BBC News
# 1     Google News
# 2     Google News
# 3     Google News
# 4    The Guardian
# ..            ...
# 743   Motley Fool
# 744   Motley Fool
# 745   Motley Fool
# 746   Motley Fool
# 747   Motley Fool
#
# [748 rows x 9 columns]
