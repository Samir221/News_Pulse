# %%
import pandas as pd
import os
import json

import requests
import re
import openai

from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chains import SimpleSequentialChain

from apikey import apikey_news_source
from apikey import apikey_openai

# %%
# Create an empty DataFrame to store the news articles
articles_df = pd.DataFrame(columns=['Source', 'Author', 'Title', 'Description', 'URL', 'Published At', 'Content'])

# Iterate over unique micro-sectors
# Format the API URL for the specific" micro-sector
#api_url = f"https://newsapi.org/v2/ev"erything?q={sector}&apiKey={apikey_news_source}"
#api_url = f"https://newsapi.org/v2/everything?q={sector}&from=2023-06-28&to=2023-05-18&apiKey={apikey_news_source}"
#api_url = f"https://newsapi.org/v2/everything?&from=2023-06-28&to=2023-05-18&apiKey={apikey_news_source}"    
api_url = f"https://newsapi.org/v2/top-headlines?country=us&from=2023-05-29&apiKey={apikey_news_source}"
    
    
# Make the API request
response = requests.get(api_url)  
    
# Process the response and extract relevant information
articles = response.json().get('articles')

if articles:
    # Extract article information and add micro-sector column
    articles_data = [(article.get('source').get('name'), article.get('author'), 
                    article.get('title'), article.get('description'), 
                    article.get('url'), article.get('publishedAt'), article.get('content'))  for article in articles]
        
    # Convert the list of articles to a DataFrame
    articles_sector_df = pd.DataFrame(articles_data, columns=['Source', 'Author', 'Title',
                                                            'Description', 'URL', 'Published At', 'Content'])
        
        # Append the articles for the current micro-sector to the main DataFrame
    articles_df = pd.concat([articles_df, articles_sector_df], ignore_index=True)


#all_articles = https://newsapi.org/v2/everything?q=bitcoin&apiKey=70e54d1dc4e6469eb7c57362bc23a044

# %%
articles_df
# Out:
#                   Source                                        Author  \
# 0               BBC News              https://www.facebook.com/bbcnews
# 1                WABC-TV                                          None
# 2                    CNN
# 3              USA Today                                 Kayla Jimenez
# 4            MarketWatch                                Jamie Chisholm
# 5           SciTechDaily                                          None
# 6    Yahoo Entertainment                Sujata Rao and Denitsa Tsekova
# 7             CBS Sports
# 8                MLB.com                               Rhett Bollinger
# 9           The Athletic  Nicole Auerbach, Bruce Feldman, Jeff Zrebiec
# 10              BBC News              https://www.facebook.com/bbcnews
# 11              Euronews                                Tokunbo Salako
# 12      Associated Press              NICHOLAS RICCARDI, DAVID A. LIEB
# 13       Foreign Affairs                               Vladislav Zubok
# 14              CBS News                                  Faris Tanyos
# 15  Entertainment Weekly                            Maureen Lee Lenker
# 16    Detroit Free Press                    Marina Johnson, Nour Rahal
# 17                 Axios                                         Axios
# 18              Buzzfeed                                  Joseph Longo
# 19                   PBS                                          None
#
#                                                 Title  \
# 0   Hajj: Price rises making pilgrimage increasing...
# 1   Travel woes worsen for passengers stranded at ...
# 2   Watch: Violence breaks out after video shows P...
# 3   Florida Gov. Ron DeSantis' feud with Disney Wo...
# 4   Stock futures fall as report of fresh chips-to...
# 5   Intermittent Fasting vs. Calorie Counting: Wha...
# 6   Europe Shares Extend Rebound From Losing Strea...
# 7   2023 MLB Mock Draft: LSU teammates, College Wo...
# 8   Shohei Ohtani homers twice, strikes out 10 vs....
# 9   Ryan Mallett, former Arkansas star and NFL QB,...
# 10  Kramatorsk: Russian missile strike hits restau...
# 11  Actor Julian Sands confirmed dead five months ...
# 12  Supreme Court rejects novel legislative theory...
# 13  Russia's New Time of Troubles - Foreign Affair...
# 14  NASCAR champion Jimmie Johnson's in-laws and t...
# 15  Meet David Corenswet, the new Superman in Jame...
# 16  Detroit air quality ranks second worst in worl...
# 17  Costco cracking down on membership card sharin...
# 18  Check Out Airbnb's Malibu Barbie DreamHouse - ...
# 19  Mississippi sheriff fires deputies accused of ...
#
#                                           Description  \
