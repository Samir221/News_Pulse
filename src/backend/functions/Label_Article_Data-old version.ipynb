# %% [markdown]
# ## Label Articles as 'Fact' or 'Opinion'

# %%
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime, timedelta

import requests
import re
import openai
from google.cloud import bigquery
from bs4 import BeautifulSoup
from newspaper import Article, Config

from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chains import SimpleSequentialChain

from apikey import apikey_news_source
from apikey import apikey_openai

# %%
all_articles_df = pd.read_csv(r'C:\Users\samir\OneDrive\Desktop\News Stock Relevance Project\all_articles.csv')

# %%
all_articles_df = all_articles_df.dropna(subset=['Description', 'Content'])

# %%
max_prompt_length = 4097

# %%
all_articles_df = all_articles_df.head(10).reset_index(drop=True)  # REMOVE IN PRODUCTION

# %%
# Define the headers you want to use
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'

# Create a configuration object
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 15 

# Classify Each Article as Fact or Opinion

# Set up OpenAI API credentials
openai.api_key = apikey_openai

# Iterate through each article
for index, row in all_articles_df.iterrows():
    link = row['URL']

    # Use Newspaper3k to parse the article
    article = Article(link, config=config)
    article.download()
    article.parse()
    full_content = article.text

    prompt_content = f"Title: {row['Title']}  Description: {row['Description']}  Full Content: {full_content}"
    
    # Prompt 2: Classify the article based on its full contents
    prompt = f"Do not mention any other details, please classify full contents of this article as only 'Fact' or 'Opinion':\n\n{prompt_content}"
        
        
    # Make API request to OpenAI API for classification
    response2 = openai.Completion.create(
    engine='text-davinci-003',
    prompt=prompt[:max_prompt_length],
    max_tokens=800,  #Adjust as needed
    temperature=0,  # Adjust as needed
    n=1  # Adjust as needed
    )
    classification = response2.choices[0].text.strip().lower()
    all_articles_df.loc[index, 'Full Content'] = prompt_content
    all_articles_df.loc[index, 'Classification'] = classification

# %%
for i, row in all_articles_df.iterrows():
    text = re.sub(r'\W+', ' ', row['Classification'])
    words = text.split()  # Split the text into words
    if 'Fact' in words or 'fact' in words :
        all_articles_df.at[i,'Classification'] = "Fact"
    elif 'Opinion' in words or 'opinion' in words :
        all_articles_df.at[i, 'Classification'] = "Opinion"

# %%
all_articles_df
# Out:
#                 Source                                        Author  \
# 0  The Washington Post                                  Dan Stillman
# 1             CBS News                                   Emmet Lyons
# 2                  CNN                                 Julia Buckley
# 3              WABC-TV                                           NaN
# 4         DW (English)                                Deutsche Welle
# 5         SciTechDaily                                           NaN
# 6             ABC News            ÉDGAR H. CLEMENTE Associated Press
# 7           CBS Sports                                           NaN
# 8         The Athletic  Nicole Auerbach, Bruce Feldman, Jeff Zrebiec
# 9                 ESPN                                Alden Gonzalez
#
#                                                Title  \
# 0  D.C.-area forecast: Sunshine and some smoke to...
# 1  Kevin Spacey's U.K. trial on sexual assault ch...
# 2  Air passenger gets plane all to himself after ...
# 3  Travel woes worsen for passengers stranded at ...
# 4  South Koreans become a year or two younger ove...
# 5  Intermittent Fasting vs. Calorie Counting: Wha...
# 6  Gunmen abduct 14 state police officers in the ...
# 7  2023 MLB Mock Draft: LSU teammates, College Wo...
# 8  Ryan Mallett, former Arkansas star and NFL QB,...
# 9  Shohei Ohtani hits 2 HRs, K's 10 in start cut ...
#
#                                          Description  \
# 0  Shower and storm chances return late Friday an...
# 1  Oscar-winning actor Kevin Spacey faces a dozen...
# 2  Everyone else made other plans when the flight...
# 3  Hundreds of flights are already canceled as of...
# 4  A new law has scrapped South Korea's tradition...
# 5  A study by the University of Illinois Chicago ...
# 6  Armed men have abducted 14 state police office...
# 7               The 2023 draft begins Sunday, July 9
# 8  A Michigan source confirmed to The Athletic th...
# 9  Shohei Ohtani hit two home runs and struck out...
#
#                                                  URL          Published At  \
# 0  https://www.washingtonpost.com/weather/2023/06...  2023-06-28T12:00:00Z
# 1  https://www.cbsnews.com/news/kevin-spacey-uk-t...  2023-06-28T11:34:00Z
# 2  https://www.cnn.com/travel/solo-air-passenger-...  2023-06-28T11:19:00Z
# 3  https://abc7ny.com/flight-cancellations-lga-ne...  2023-06-28T09:11:15Z
# 4  https://www.dw.com/en/south-koreans-become-a-y...  2023-06-28T08:48:52Z
# 5                 https://scitechdaily.com/?p=288129  2023-06-28T08:33:24Z
# 6  https://abcnews.go.com/International/wireStory...  2023-06-28T08:04:26Z
# 7  https://www.cbssports.com/mlb/news/2023-mlb-mo...  2023-06-28T06:32:00Z
# 8  https://theathletic.com/4646091/2023/06/27/rya...  2023-06-28T05:31:31Z
# 9  https://www.espn.com/mlb/story/_/id/37925744/s...  2023-06-28T05:09:00Z
#
#                                              Content  \
# 0  Comment on this story\r\nComment\r\n* Code Ora...
# 1  London – Kevin Spacey's trial began Wednesday ...
# 2  If youve ever thought that having an empty sea...
# 3  EAST ELMHURST, Queens (WABC) -- Hundreds of fl...
# 4  People in South Korea woke up on Wednesday to ...
# 5  ByAmerican College of PhysiciansJune 28, 2023\...
# 6  MEXICO CITY -- Armed men abducted 14 state pol...
# 7  The 2023 MLB Draft is a little more than two w...
# 8  By Nicole Auerbach, Bruce Feldman and Jeff Zre...
# 9  ANAHEIM, Calif. -- The diagnosis blared throug...
#
#                                         Full Content Classification
# 0  D.C.-area forecast: Sunshine and some smoke to...           Fact
# 1  Kevin Spacey's U.K. trial on sexual assault ch...           Fact
# 2  Air passenger gets plane all to himself after ...           Fact
# 3  Travel woes worsen for passengers stranded at ...           Fact
# 4  South Koreans become a year or two younger ove...           Fact
# 5  Intermittent Fasting vs. Calorie Counting: Wha...           Fact
# 6  Gunmen abduct 14 state police officers in the ...           Fact
# 7  2023 MLB Mock Draft: LSU teammates, College Wo...           Fact
# 8  Ryan Mallett, former Arkansas star and NFL QB,...           Fact
# 9  Shohei Ohtani hits 2 HRs, K's 10 in start cut ...           Fact

# %%
all_articles_df.to_csv("articles.csv", index=False)
